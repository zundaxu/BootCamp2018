# %% [markdown]
# ### Problem Set 2
#
# #### Name: Zunda Xu ( zunda@uchicago.edu )

# %%
import random
from scipy import stats
import math
from scipy import special
from numpy.polynomial.polynomial import polyfit

# %% [markdown]
# ### Data Visualization 1 Introduction to Matplotlip

# %% [markdown]
# #### Problem 1

# %%
def draw_random_sample(n):
    matrix = np.random.normal(size = (n,n))
    mean_value = np.mean(matrix, axis = 1)
    variance = np.var(mean_value)
    return variance

def plot_random_sample():
    inputs = np.arange(100, 500, 100)
    arr = []
    for i in range(len(inputs)):
        arr.append(draw_random_sample(inputs[i]))

    plt.plot(arr)
    plt.show()
    
plot_random_sample()

# %% [markdown]
# #### Problem 2

# %%
x = np.linspace(-2*np.pi,2*np.pi,100);
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.arctan(x)

# %%
plt.plot(x, y1, x, y2, x, y3)
plt.show()

# %% [markdown]
# #### Problem 3

# %%
x_1 = np.linspace(-2,1)
x_2 = np.linspace(1,6)
def f(x):
    return (1/(x-1))
f1=f(x_1)
f2=f(x_2)
plt.plot(x_1, f1, x_2, f2)
plt.show()
# Out:
# /Users/winston/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %% [markdown]
# #### Problem 4

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.sin(2*x)
y3 = 2*np.sin(x)
y4 = 2*np.sin(2*x)

ax1 = plt.subplot(2,2,1)
ax1.plot(x, y1)
ax2 = plt.subplot(2,2,2)
ax2.plot(x, y2)
ax3 = plt.subplot(2,2,3)
ax3.plot(x, y3)
ax4 = plt.subplot(2,2,4)
ax4.plot(x, y4)

plt.show()

# %%
def visualizeFars():
    fars = np.load("FARS.npy")
    hours_arr = fars[:, 0]
    longitude_arr = fars[:, 1]
    latitude_arr = fars[:, 2]

    fig, ax = plt.subplots(1,2)
    ax[0].plot(latitude_arr, longitude_arr, "o", markersize = 0.05)
    ax[0].set_xlabel("Latitude")
    ax[0].set_ylabel("Longitude")
    ax[0].set_aspect("equal")

    ax[1].hist(hours_arr, bins = np.arange(-0.5, 24.5))
    ax[1].set_xlabel("Hours")
    plt.show()

visualizeFars()

# %% [markdown]
# #### Problem 6

# %%
def three_d_plot():
    x_array = np.linspace(-2*np.pi, 2*np.pi, 100)
    y_array = np.linspace(-2*np.pi, 2*np.pi, 100)
    X, Y = np.meshgrid(x_array, y_array)
    Z = np.sin(X)*np.sin(Y)/(X*Y)

    plt.figure(figsize = [12, 5])
    plt.subplot(1,2,1)
    plt.pcolormesh(X, Y, Z, cmap = "viridis")
    plt.axis([-2*np.pi, 2*np.pi, -2*np.pi, 2*np.pi])
    plt.colorbar()


    plt.subplot(1,2,2)
    plt.contour(X, Y, Z, cmap = 'coolwarm')
    plt.axis([-2*np.pi, 2*np.pi, -2*np.pi, 2*np.pi])
    plt.colorbar()

    plt.show()
    
three_d_plot()

# %% [markdown]
# ### Data Visualization 2

# %%
def visualizeAnscombe():
    temp = np.load("anscombe.npy")
    section1 = temp[:, 0:2]
    section2 = temp[:, 2:4]
    section3 = temp[:, 4:6]
    section4 = temp[:, 6:8]


    plt.figure(figsize = [8,8])

    #section1
    plt.subplot(2,2,1)
    plt.plot(section1[:,0], section1[:,1], "o", markersize = 4)
    plt.xlim(0, 20)
    plt.ylim(0, 13)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Section 1")

    temp1 = stats.linregress(section1[:,0], section1[:,1])
    slope1, intercept1, coeff1 = temp1[0], temp1[1], temp1[2]
    regress_x1 = np.linspace(0, 20, 20)
    regress_y1 = slope1 * regress_x1 + intercept1
    plt.plot(regress_x1, regress_y1)



    #section2
    plt.subplot(2,2,2)
    plt.plot(section2[:,0], section2[:,1], "o", markersize = 4)
    plt.xlim(0, 20)
    plt.ylim(0, 13)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Section 2")

    temp2 = stats.linregress(section2[:,0], section2[:,1])
    slope2, intercept2, coeff2 = temp2[0], temp2[1], temp2[2]
    regress_x2 = np.linspace(0, 20, 20)
    regress_y2 = slope2 * regress_x2 + intercept2
    plt.plot(regress_x2, regress_y2)



    #section3
    plt.subplot(2,2,3)
    plt.plot(section3[:,0], section3[:,1], "o", markersize = 4)
    plt.xlim(0, 20)
    plt.ylim(0, 13)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Section 3")

    temp3 = stats.linregress(section3[:,0], section3[:,1])
    slope3, intercept3, coeff3 = temp3[0], temp3[1], temp3[2]
    regress_x3 = np.linspace(0, 20, 20)
    regress_y3 = slope3 * regress_x3 + intercept3
    plt.plot(regress_x3, regress_y3)



    #section 4
    plt.subplot(2,2,4)
    plt.plot(section4[:,0], section4[:,1], "o", markersize = 4)
    plt.xlim(0, 20)
    plt.ylim(0, 13)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Section 4")

    temp4 = stats.linregress(section4[:,0], section4[:,1])
    slope4, intercept4, coeff4 = temp4[0], temp4[1], temp4[2]
    regress_x4 = np.linspace(0, 20, 20)
    regress_y4 = slope4 * regress_x4 + intercept4
    plt.plot(regress_x4, regress_y4)
    
    print("Section 1. ", "x mean: ", np.round(section1[:,0].mean(),2), " y mean: ", np.round(section1[:,1].mean(),2),
          " x var: ", np.round(np.var(section1[:, 0]),2), " y var: ", np.round(np.var(section1[:, 1]), 2),
          " slop: ", np.round(slope1, 2), " intercept: ", np.round(intercept1, 2), " correlation: ", np.round(coeff1, 2))
    print("Section 2. ", "x mean: ", np.round(section2[:,0].mean(),2), " y mean: ", np.round(section2[:,1].mean(),2),
          " x var: ", np.round(np.var(section2[:, 0]),2), " y var: ", np.round(np.var(section2[:, 1]), 2),
          " slop: ", np.round(slope2, 2), " intercept: ", np.round(intercept2, 2), " correlation: ", np.round(coeff2, 2))
    print("Section 3. ", "x mean: ", np.round(section3[:,0].mean(),2), " y mean: ", np.round(section3[:,1].mean(),2),
          " x var: ", np.round(np.var(section3[:, 0]),2), " y var: ", np.round(np.var(section3[:, 1]), 2),
          " slop: ", np.round(slope3, 2), " intercept: ", np.round(intercept3, 2), " correlation: ", np.round(coeff3, 2))
    print("Section 4. ", "x mean: ", np.round(section4[:,0].mean(),2), " y mean: ", np.round(section4[:,1].mean(),2),
          " x var: ", np.round(np.var(section4[:, 0]),2), " y var: ", np.round(np.var(section4[:, 1]), 2),
          " slop: ", np.round(slope4, 2), " intercept: ", np.round(intercept4, 2), " correlation: ", np.round(coeff4, 2))

    print("Although the scatter plots show that they are different, they have similar statistical data.")

# %%
visualizeAnscombe()
# Out:
# Section 1.  x mean:  9.0  y mean:  7.5  x var:  10.0  y var:  3.75  slop:  0.5  intercept:  3.0  correlation:  0.82
# Section 2.  x mean:  9.0  y mean:  7.5  x var:  10.0  y var:  3.75  slop:  0.5  intercept:  3.0  correlation:  0.82
# Section 3.  x mean:  9.0  y mean:  7.5  x var:  10.0  y var:  3.75  slop:  0.5  intercept:  3.0  correlation:  0.82
# Section 4.  x mean:  9.0  y mean:  7.5  x var:  10.0  y var:  3.75  slop:  0.5  intercept:  3.0  correlation:  0.82
# Although the scatter plots show that they are different, they have similar statistical data.

# %% [markdown]
# #### Problem 2

# %%
def BernsteinPolynomials():
    SMALL_SIZE = 8
    MEDIUM_SIZE = 10
    BIGGER_SIZE = 12

    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)

    Coeff = np.zeros((4,4))
    for n in range(4):
        for v in range(n+1):
            Coeff[n,v] = special.binom(n, v)

    x_grid = np.linspace(0,1,50)

    temp = np.zeros_like(x_grid)

    y_matrix = np.tile(temp, (17,1))

    for nn in range(4):
        for vv in range(nn+1):
            y_matrix[4*nn+vv+1, :] = Coeff[nn,vv] * x_grid**vv * (1-x_grid)**(nn-vv)
            plt.subplot(4,4, 4 * nn + vv + 1)
            plt.title(r"$n=$" + str(nn) + r"$, v=$" + str(vv))
            plt.plot(x_grid, y_matrix[4*nn+vv+1, :])
            plt.xlim(0, 1)
            plt.ylim(0, 1.5)


    plt.tight_layout()
    plt.show()

BernsteinPolynomials()

# %% [markdown]
# #### Problem 3

# %%
def height_Weight_Age():
    data = np.load("MLB.npy")
    height = data[:,0]
    weight = data[:,1]
    age = data[:,2]
    plt.figure(figsize = [15, 5])
    plt.subplot(1,3,1)
    plt.plot(height, weight, "o", markersize = 4, alpha = 0.5)
    plt.xlabel("Height")
    plt.ylabel("Weight")
    plt.title("Weight and height")
    interc, slo = polyfit(height, weight, 1)
    plt.plot(height, interc + slo * height)

    plt.subplot(1,3,2)

    plt.hist(weight)
    plt.ylabel("Weight")
    plt.title("Distribution of Weight")

    plt.subplot(1,3,3)

    plt.hist(height)
    plt.ylabel("Height")
    plt.title("Distribution of Height")
    plt.show()

height_Weight_Age()

# %% [markdown]
# #### Problem 4

# %%
def visualize_Earth_quakes():
    data = np.load("earthquakes.npy")
    date = data[:, 0]
    magnitude = data[:, 1]
    longitude = data[:, 2]
    latitude = data[:, 3]

    plt.figure(figsize = [12,4])
    plt.subplot(1,3,1)
    plt.hist(date, bins = np.arange(2000, 2011))
    plt.xlabel("Year")
    plt.ylabel("Number of Earthquakes")
    plt.title("Number of Earthquakes by Year")

    plt.subplot(1,3,2)
    plt.hist(magnitude)
    plt.xlabel("Magnitude")
    plt.ylabel("Number of Earthquakes")
    plt.title("Number of Earthquakes Levels")

    plt.subplot(1,3,3)
    plt.plot(longitude, latitude, "o", markersize = 2, alpha = 0.5)
    plt.axis("equal")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(" Earthquakes Geographic Imformation")

    plt.tight_layout()
    plt.show()

visualize_Earth_quakes()

# %% [markdown]
# #### Problem 5

# %%
def Rosen_brock():
    x = np.linspace(0.9, 1.1, 100)
    y = np.linspace(0.9, 1.1, 100)
    X, Y = np.meshgrid(x, y)
    Z = (1-X)**2 + 100 * ((Y - X**2)**2)

    plt.figure(figsize = [8, 4])
    plt.subplot(1,2,1)
    plt.pcolormesh(X, Y, Z, cmap = "inferno")
    plt.plot(1, 1, "ro")
    plt.colorbar()
    plt.title("Heat map")

    plt.subplot(1,2,2)
    plt.contour(X, Y, Z, 30, cmap = "magma")
    plt.plot(1, 1, "ko")
    plt.title("Contour Plot")


    plt.show()
    
Rosen_brock()

# %% [markdown]
# #### Problem 6

# %%
def visualizeCountries():
    SMALL_SIZE = 8
    MEDIUM_SIZE = 10
    BIGGER_SIZE = 12

    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)

    data = np.load("countries.npy")
    names =  np.array(["Austria", "Bolivia", "Brazil", "China",
            "Finland", "Germany", "Hungary", "India",
            "Japan", "North Korea", "Montenegro", "Norway",
            "Peru", "South Korea", "Sri Lanka", "Switzerland",
            "Turkey", "United Kingdom", "United States", "Vietnam"])
    
    #20 countries
    population = data[:, 0]
    GDP = data[:, 1]
    male_height = data[:, 2]
    female_height = data[:, 3]

    plt.figure(figsize = [15,15])

    #sort by GDP from largest to smallest
    GDP_index = np.argsort(GDP)


    plt.subplot(2,2,1)

    positions = np.arange(20)
    plt.barh(positions, GDP[GDP_index], align="center")

    plt.yticks(positions, names[GDP_index])
    plt.xlabel("GDP in billions of US dollars")

    plt.subplot(2,2,2)
    population_index = np.argsort(population)
    plt.barh(positions, population[population_index], align = "center")
    plt.yticks(positions, names[population_index])
    plt.xlabel("Population")

    plt.subplot(2,2,3)
    plt.plot(male_height, female_height, "mo", markersize = 4, alpha = 0.5)
    plt.xlabel("Male height")
    plt.ylabel("Female height")

    plt.subplot(2,2,4)
    GDP_percapita = np.empty_like(GDP)
    GDP_percapita = GDP / population
    plt.hist(GDP_percapita)
    plt.xlabel("GDP per capita")
    plt.ylabel("Number of countries")
    plt.show()

visualizeCountries()
# Out:
# Conclusions:
# 1, it can be seen US and China dominate in GDP and China and India dominate in population.
# 2, it can be seen that male height an female height are heighly correlated
# 3, it can be seen that most countries still have low gpd GDP per capita.

# %% [markdown]
# Conclusions:
# It can be seen US and China dominate in GDP and China and India dominate in population. Secondly, male height an female height are heighly correlated. Third, most countries still have low gpd GDP per capita.

# %% [markdown]
# ### Pandas 1

# %% [markdown]
# #### Problem 1

# %%
def pandas_1():
    i = np.arange(0,52,2)
    v = i**2 - 1
    s = pd.Series(v, index = i)

    new_index = (i % 3 == 0)
    s[new_index] = 0
    print(s)

pandas_1()
# Out:
# 0        0
# 2        3
# 4       15
# 6        0
# 8       63
# 10      99
# 12       0
# 14     195
# 16     255
# 18       0
# 20     399
# 22     483
# 24       0
# 26     675
# 28     783
# 30       0
# 32    1023
# 34    1155
# 36       0
# 38    1443
# 40    1599
# 42       0
# 44    1935
# 46    2115
# 48       0
# 50    2499
# dtype: int64

# %% [markdown]
# #### Problem 2

# %%
def walk(prob, d=100):
    days = pd.date_range("1/1/2000", "12/31/2000", freq='D')
    s = np.zeros(len(days))
    s[0] = d
    c = [1,-1]
    for i in range(1, len(days)):
        s[i] = s[i-1] + np.random.choice(c, p = [prob, 1-prob])
    return(pd.Series(s, index=days))

# %%
plt.plot(walk(0.5))
plt.show()

# %% [markdown]
# #### Problem 3

# %%
name = ['Mylan', 'Regan', 'Justin', 'Jess', 'Jason', 'Remi', 'Matt', 'Alexander', 'JeanMarie']
sex = ['M', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'F']
age = [20, 21, 18, 22, 19, 20, 20, 19, 20]
rank = ['Sp', 'Se', 'Fr', 'Se', 'Sp', 'J', 'J', 'J', 'Se']
ID = range(9)
aid = ['y', 'n', 'n', 'y', 'n', 'n', 'n', 'y', 'n']
GPA = [3.8, 3.5, 3.0, 3.9, 2.8, 2.9, 3.8, 3.4, 3.7]
mathID = [0, 1, 5, 6, 3]
mathGd = [4.0, 3.0, 3.5, 3.0, 4.0]
major = ['y', 'n', 'y', 'n', 'n']
studentInfo = pd.DataFrame({'ID': ID, 'Name': name, 'Sex': sex, 'Age': age, 'Class': rank})
otherInfo = pd.DataFrame({'ID': ID, 'GPA': GPA, 'Financial_Aid': aid})
mathInfo = pd.DataFrame({'ID': mathID, 'Grade': mathGd, 'Math_Major': major})

# %%
studentInfo.query("Age > 19 & Sex == 'M'")[["ID", "Name"]]
# Out:
#    ID   Name
# 0   0  Mylan
# 6   6   Matt

# %% [markdown]
# #### Problem 4

# %%
pd.merge(studentInfo, otherInfo, on="ID")
# Out:
#    Age Class  ID       Name Sex Financial_Aid  GPA
# 0   20    Sp   0      Mylan   M             y  3.8
# 1   21    Se   1      Regan   F             n  3.5
# 2   18    Fr   2     Justin   M             n  3.0
# 3   22    Se   3       Jess   F             y  3.9
# 4   19    Sp   4      Jason   M             n  2.8
# 5   20     J   5       Remi   F             n  2.9
# 6   20     J   6       Matt   M             n  3.8
# 7   19     J   7  Alexander   M             y  3.4
# 8   20    Se   8  JeanMarie   F             n  3.7

# %% [markdown]
# #### Problem 5

# %%
def pd_problem_5():
    data = pd.read_csv("crime_data.txt", skiprows = 1, index_col = "Year")
    data["Crime_rate"] = data["Total"]/data["Population"]
    plt.figure(figsize=[8,4])
    plt.subplot(1,2,1)
    plt.plot(data.index, data["Crime_rate"])
    plt.xlabel("Year")
    plt.ylabel("Crime rate")
    plt.title("Crime rate in each year")
    print("Below are 5 years with the highest crime rate:")
    print(data.sort_values("Crime_rate", ascending = False).iloc[0:5, :])

    subdata = data.loc[1960:2012,]
    avg_total = subdata["Total"].mean()
    avg_Burglary = subdata["Burglary"].mean()
    print("The average number of toal crimes between 1960 and 2012 is", avg_total)
    print("The average number of toal burglaries between 1960 and 2012 is", avg_Burglary)
    print()
    print("Below are years s.t. the total number of crimes was below average, but the number of burglaries was above average:")
    print(subdata[subdata["Total"]<avg_total][subdata[subdata["Total"]<avg_total]["Burglary"]>avg_Burglary].index)

    plt.subplot(1,2,2)
    plt.plot(data["Population"], data["Murder"])
    plt.xlabel("Population")
    plt.ylabel("Murder")
    plt.title("Murder as a function of population")

    print()

    data_subset = data.loc[1980:1989][["Population", "Violent", "Robbery"]]
    data_subset.to_csv("crime_subset.csv")

    plt.tight_layout()
    plt.show()

pd_problem_5()
# Out:
# Below are 5 years with the highest crime rate:
#       Population     Total  Violent  Property  Murder  Forcible-Rape  Robbery  \
# Year
# 1980   225349264  13408300  1344520  12063700   23040          82990   565840
# 1991   252177000  14872900  1911770  12961100   24700         106590   687730
# 1981   229146000  13423800  1361820  12061900   22520          82500   592910
# 1990   248709873  14475600  1820130  12655500   23440         102560   639270
# 1989   248239000  14251400  1646040  12605400   21500          94500   578330
#
#       Aggravated-assault  Burglary  Larcency-Theft  Vehicle-Theft  Crime_rate
# Year
# 1980              672650   3795200         7136900        1131700    0.059500
# 1991             1092740   3157200         8142200        1661700    0.058978
# 1981              663900   3779700         7194400        1087800    0.058582
# 1990             1054860   3073900         7945700        1635900    0.058203
# 1989              951710   3168200         7872400        1564800    0.057410
# The average number of toal crimes between 1960 and 2012 is 10638068.075471697
# The average number of toal burglaries between 1960 and 2012 is 2446286.2075471696
#
# Below are years s.t. the total number of crimes was below average, but the number of burglaries was above average:
# Int64Index([1973, 1974], dtype='int64', name='Year')

# %% [markdown]
# ### Pandas 2

# %%
Arbuthnot = data("Arbuthnot")
Arbuthnot.plot(x = "Year", y = ['Males', 'Females'], kind = "line")
plt.title("Number of males and females born each year.")
plt.show()

# %%
Arbuthnot.plot(kind = "scatter", x = "Males", y = "Females")
plt.title("Correlation between male birth and female birth")
plt.show()

# %%
bir = data("birthdeathrates")

bir["birth"].hist()
plt.tight_layout()
plt.xlabel("Birth rate per mil")
plt.title("Histogram of birth rates")
plt.show()

# %%
bir.plot(kind = "scatter" , x = "birth", y = "death")
plt.xlabel("Birth rate per mil")
plt.ylabel("Death rate per mil")
plt.title("Correlation between birth rate and death rate")
plt.show()

# %%
trees = data("trees")
trees.plot(x = "Girth", y = "Volume", kind = "hexbin", gridsize = 20)
plt.title("correlation between volume and girth of black cherry trees")
plt.show()

# %%
trees["Height"].hist(grid = False)
plt.xlabel("Height")
plt.title("Distribution of height of cherry trees")
plt.show()

# %%
road = data("road")
road.plot(kind = "barh", y = "deaths", legend = False)
plt.title("Death from traffic accidents in each state")
plt.show()

# %%
road.plot(kind = "scatter", x = "drivers", y = "deaths")
plt.xlabel("Drivers in 100,000s")
plt.title("Correlation between number of drivers and traffic death in each state")
plt.show()

# %%
lung = data("lung")
lung.plot(kind = "hist", y = "time")
plt.title("Distribution of surviving time")
plt.xlabel("Surviving time")
plt.show()

# %%
lung.plot(kind = "hexbin", x="age", y = "time", gridsize = 20)
plt.title("Correlation between age and surviving time")
plt.show()

# %% [markdown]
# ### Pandas 3 Group

# %%
from pydataset import data
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### Problem 1

# %%
iris = data("iris")

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
iris_species = iris.groupby("Species")
iris_species[["Sepal.Length", "Sepal.Width", "Petal.Length", "Petal.Width"]].mean().plot(kind = "barh")
plt.title("Compare three species of Iris")
plt.show()

# %% [markdown]
# From the graph above, we notice that setosa has the smallest petal width and petal length compared with other two species, so setaso is the easiest to distinguish

# %% [markdown]
# The strategy are as follows:

# %% [markdown]
# If the flower has significantly smaller petal width and petal length, it tends to be setosa, while if the flower has larger sepal lenth and larger petal lenth, it tends to be virginica. Otherwise it will be versicolor.

# %%
poisons = data("poisons")
poisons.head()
# Out:
#    time  poison treat
# 1  0.31       1     A
# 2  0.45       1     A
# 3  0.46       1     A
# 4  0.43       1     A
# 5  0.36       2     A

# %%
groupby_poisons = poisons.groupby("poison")
groupby_poisons["time"].mean().plot(kind= "barh", xerr = groupby_poisons.std(), legend = True)
plt.ylabel("Poison type")
plt.title("Average surviivng time")
plt.show()

# %% [markdown]
# From the graph shown above, we can see that poison type 3 is the most effective.

# %%
poison_by_treat = poisons.groupby("treat")
poison_by_treat["time"].mean().plot(kind= "barh", xerr = poison_by_treat.std(), legend = True)
plt.show()

# %% [markdown]
# From the graph shown above, we can see that treatment B is the most effective.

# %%
poi_1 = poisons.groupby("poison").get_group(1)
poi_2 = poisons.groupby("poison").get_group(2)
poi_3 = poisons.groupby("poison").get_group(3)
poi_1_treat = poi_1.groupby("treat")
poi_2_treat = poi_2.groupby("treat")
poi_3_treat = poi_3.groupby("treat")

# %%
poi_1_treat["time"].mean().plot(kind = "barh", title = "Comparison of treatment for poision type 1")
plt.show()

# %%
poi_2_treat["time"].mean().plot(kind = "barh", title = "Comparison of treatment for poision type 2")
plt.show()

# %%
poi_3_treat["time"].mean().plot(kind = "barh", title = "Comparison of treatment for poision type 3")
plt.show()

# %% [markdown]
# If we don't know the type of poison, treatment B would be the best choice.
# If it is poison type 1, one should choose treatment B.
# If it is poison type 2, one should still choose treatment B.
# If it is poison type 3, treatment B and treatment D are better choice.

# %%
diamonds  = data("diamonds")
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.boxplot(["price"], by=["cut"], grid = False)
plt.show()
# Out:
# /Users/winston/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
diamonds.boxplot(["price"], by=["color"], grid = False)
plt.show()
# Out:
# /Users/winston/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# It is hard to conclude since both of them have many outliers. However, we can still see that better color and better cut yield heigher prices.

# %%
diamond_c = diamonds.groupby("color").get_group("H")
diamond_c_f = diamond_c.groupby("cut").get_group("Fair")
diamond_c_s = diamond_c.groupby("cut").get_group("Ideal")
print("Average size of color H diamonds with fair cut: ", diamond_c_f["carat"].mean())
print("Average size of color H diamonds with ideal cut: ", diamond_c_s["carat"].mean())
# Out:
# Average size of color H diamonds with fair cut:  1.2191749174917463
# Average size of color H diamonds with ideal cut:  0.7995248796147678

# %% [markdown]
# Therefore, the reason that the first categoty generally sells higher prices is that such diamonds are by nature larger.

# %% [markdown]
# #### Problem 3

# %%
npk = data("npk")
npk.head()
# Out:
#    block  N  P  K  yield
# 1      1  0  1  1   49.5
# 2      1  1  1  0   62.8
# 3      1  0  0  0   46.8
# 4      1  1  0  1   57.0
# 5      2  1  0  0   59.8

# %%
npk_n = npk[npk["N"]==1]
npk_p = npk[npk["P"]==1]
npk_k = npk[npk["K"]==1]
plt.bar(x=["N","P","C"], height = [npk_n["yield"].mean(), npk_p["yield"].mean(), npk_k["yield"].mean()])
plt.title("Average yield of using N, P, or K")
plt.show()

# %% [markdown]
# From the graph above, we note that Nitrogen is the most effective one.

# %%
npk_prime = npk.pivot_table(values = "yield", index = ["N", "P", "K"])
npk_prime
# Out:
#            yield
# N P K
# 0 0 0  51.433333
#     1  52.000000
#   1 0  54.333333
#     1  50.500000
# 1 0 0  63.766667
#     1  54.666667
#   1 0  57.933333
#     1  54.366667

# %%
npk_prime.plot(kind = "barh")
plt.show()

# %% [markdown]
# From the graph above, we find using only nitrogen is the best. Using both P and K is the worst.

# %%
swiss = data("swiss")
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
swiss.plot(kind = "scatter", x = "Fertility", y="Infant.Mortality")
plt.title("Correlation between Fertility and Infant Mortality")
plt.show()

# %% [markdown]
# In general, fertility and infant mortality are positively correlated.

# %%
cath = pd.cut(swiss["Catholic"], np.arange(0, 110, 10))
swiss.pivot_table(values = [ "Fertility"], index = cath)
# Out:
#            Fertility
# Catholic
# (0, 10]    67.895000
# (10, 20]   62.233333
# (20, 30]   68.300000
# (30, 40]   85.800000
# (40, 50]   35.000000
# (50, 60]   43.750000
# (60, 70]         NaN
# (70, 80]         NaN
# (80, 90]   83.100000
# (90, 100]  80.380000

# %% [markdown]
# Hence, provinces that are highly catholic tend to have higher fertility

# %%
swiss.plot( y = "Fertility", x = "Agriculture", kind = "scatter")
swiss.plot( y = "Fertility", x = "Examination", kind = "scatter")
swiss.plot( y = "Fertility", x = "Education", kind = "scatter")
swiss.plot( y = "Fertility", x = "Catholic", kind = "scatter")
swiss.plot( y = "Fertility", x = "Infant.Mortality", kind = "scatter")

# %% [markdown]
# From the graph shown above, mortality and agriculture are the most important factors for predicting fertility

# %% [markdown]
# ### Pandas 5

# %% [markdown]
# #### Problem 1

# %%
djia = pd.read_csv("DJIA.csv")
date_index = pd.to_datetime(djia["DATE"])

djia["VALUE"][djia["VALUE"]=="."]="NaN"

new_djia = pd.Series([float(x) for x in djia["VALUE"]], index = date_index)
new_djia = new_djia.dropna()
new_djia.plot()
plt.title("Dow Johns Index on each day")
plt.show()

# %% [markdown]
# #### Problem 2

# %%
paychecks = pd.read_csv("paychecks.csv", header = None, skiprows = 0, names = ["Wage"])
len(paychecks)
# Out:
# 93

# %%
date_range_1 = pd.date_range(start = "3/13/2008", end = "6/1/2018", freq = "WOM-1FRI")
date_range_2 = pd.date_range(start = "3/13/2008", end = "6/1/2018", freq = "WOM-3FRI")
date_range = date_range_1.union(date_range_2)
date_range = date_range[0:len(paychecks)]

pays = pd.Series(data = [float(x) for x in paychecks["Wage"]], index = date_range)
pays.plot()
plt.title("93 paychecks")
plt.ylim(500, 1500)
plt.xlabel("Date")
plt.ylabel("Wage")
plt.show()

# %% [markdown]
# #### Problem 4

# %%
finance = pd.read_csv("finances.csv")
per=pd.period_range("1978-09","1999-08",freq="Q-AUG")
finance.index=per
finance.head()
# Out:
#          EARNINGS   EXPENSES
# 1979Q1  372572.16  122611.27
# 1979Q2  419440.58  133176.18
# 1979Q3  419766.49  154670.69
# 1979Q4  361453.31  209360.42
# 1980Q1  354463.33  174147.13

# %% [markdown]
# #### Problem 5

# %%
website = pd.read_csv("website_traffic.csv")
enter = pd.to_datetime(website["ENTER"])
leave = pd.to_datetime(website["LEAVE"])

website["DURATION"] = leave-enter
website["DURATION"] = website["DURATION"].dt.total_seconds().astype(int)

enter_index = pd.to_datetime(website["ENTER"])
website.index = enter_index
website.drop("ENTER",axis=1)
website.index.names=['enter time']
minutes = website.resample("T")
m = minutes["DURATION"].mean()
hours=website.resample("H")
h=hours["DURATION"].mean()
plt.figure(figsize=(30,10))
ax1=h.plot(label='average duration per hour')
ax2=m.plot(label='average duration per minute')

ax1.legend(loc=1)
ax2.legend(loc=2)
plt.title("Website traffic")
plt.show()

# %% [markdown]
# #### Problem 5

# %%
diff_in_day = new_djia - new_djia.shift(1)
print("The single day with the largest gain: ",diff_in_day.idxmax(), "value: ", diff_in_day.max())
print("The single day with the largest loss: ",diff_in_day.idxmin(), "value: ", diff_in_day.min())
months = new_djia.resample('M')
diff_in_month = months.last() - months.first()
print("The month with the largest gain: ",diff_in_month.idxmax(), "value: ", diff_in_month.max())
print("The month with the largest loss: ",diff_in_month.idxmin(), "value: ", diff_in_month.min())
# Out:
# The single day with the largest gain:  2008-10-13 00:00:00 value:  936.42
# The single day with the largest loss:  2008-09-29 00:00:00 value:  -777.68
# The month with the largest gain:  2015-10-31 00:00:00 value:  1391.53
# The month with the largest loss:  2008-10-31 00:00:00 value:  -1506.06

# %% [markdown]
# #### Problem 6

# %%
ax1=plt.subplot(1,1,1)
new_djia.plot(color="gray", lw=.3,ax=ax1)
new_djia.rolling(window=30).mean().plot(lw=1,ax=ax1)
new_djia.ewm(span=30).mean().plot(lw=1,ax=ax1)
new_djia.rolling(window=30).max().plot(lw=1,ax=ax1)
new_djia.rolling(window=30).min().plot(lw=1,ax=ax1)
ax1.legend(["Actual", "Rolling_avg","EWMA","Rolling_max","Rolling_min"], loc="lower right")
ax1.set_title("Window = 30")
# Out:
# Text(0.5,1,'Window = 30')

# %%
ax2=plt.subplot(1,1,1)
new_djia.plot(color="gray", lw=.3,ax=ax2)
new_djia.rolling(window=120).mean().plot(lw=1,ax=ax2)
new_djia.ewm(span=120).mean().plot(lw=1,ax=ax2)
new_djia.rolling(window=120).max().plot(lw=1,ax=ax2)
new_djia.rolling(window=120).min().plot(lw=1,ax=ax2)
ax2.legend(["Actual", "Rolling_avg","EWMA","Rolling_max","Rolling_min"], loc="lower right")
ax2.set_title("Window = 120")
plt.show()

# %%
ax3=plt.subplot(1,1,1)
new_djia.plot(color="gray", lw=.3,ax=ax3)
new_djia.rolling(window=365).mean().plot(lw=1,ax=ax3)
new_djia.ewm(span=365).mean().plot(lw=1,ax=ax3)
new_djia.rolling(window=365).max().plot(lw=1,ax=ax3)
new_djia.rolling(window=365).min().plot(lw=1,ax=ax3)
ax3.legend(["Actual", "Rolling_avg","EWMA","Rolling_max","Rolling_min"], loc="lower right")
ax3.set_title("Window = 365")
plt.show()

# %% [markdown]
# ### Problem 8

# %% [markdown]
# The following code refer to Fiona Fan

# %%
from datetime import datetime
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from datetime import datetime
import itertools as it

# %%
lipids = pd.read_csv("lipids.csv", skiprows=4)
lipids = lipids[lipids['diseased'] == 1]

# %% [markdown]
# #### (1)

# %%
fig, ax = plt.subplots()
n, bins = plt.hist(lipids["chol"], bins=25)[0], plt.hist(lipids['chol'], bins = 25)[1]
plt.xlabel("Cholesteral")
plt.ylabel("Frequency")
plt.show()
chol = pd.cut(lipids["chol"], 25)
print(f"The midpoint of the bin with the highest frequency is { np.array([bins[n.argmax()], bins[n.argmax()+1]]).mean()}")
# Out:
# The midpoint of the bin with the highest frequency is 236.04000000000002

# %% [markdown]
# #### (2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(lipids['chol'], lipids['trig'], bins=25)

xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25)
xpos = xpos.flatten('F')
ypos = ypos.flatten('F')
zpos = np.zeros_like(xpos)

dx = 0.5 * np.ones_like(zpos)
dy = dx.copy()
dz = hist.flatten()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b')

ax.set_xlabel('Concentration of Cholesterol')
ax.set_ylabel('Concentration of Triglicerides')
ax.set_zlabel('Frequency')

plt.title('Cholesterol and Triglicerides Levels')
plt.show()

# %% [markdown]
# The riskiest level of cholesteral is around 150-250, while hte most normal level of trilicerides is around 400-600.

# %% [markdown]
# #### (3)

# %%
payems = pd.read_csv("payems.csv")
payems['PAYEMS'] = payems['PAYEMS'] * 1000
payems['DATE'] = pd.to_datetime(payems['DATE'])
payems.iloc[:358,0] = payems.iloc[:358,0] - pd.DateOffset(years=100)
payems = payems.set_index('DATE')
recStart = np.array(['2007-12-01', '2001-03-01', '1990-07-01', '1981-07-01', 
                           '1980-07-01', '1973-11-01', '1969-12-01', '1960-04-01',
                           '1957-08-01', '1953-07-01', '1948-11-01', '1945-02-01',
                           '1937-07-01', '1929-07-01'], dtype ='datetime64')

for i in range(9):
    payems = payems.append([payems.iloc[i]]*11)
payems = payems.sort_index(axis=0)

jobGrowth = np.empty((14,137))
startid = []

for i in range(12):
    startid.append(payems.index.get_loc(recStart[i]))
    
startid.append(100)
startid.append(12)


for ii in range(14):
    jobGrowth[ii] = list(payems.iloc[startid[ii]-12:startid[ii]+125, 0])
        
row_start = jobGrowth[:,0]
jobGrowth = jobGrowth / row_start[:,None]

fig, ax = plt.subplots(figsize = (10,10))
for ii in range(14):
    if ii == 0:
        plt.plot(jobGrowth[ii], 'r-', lw=4, label=recStart[ii])
    elif ii == 12:
        plt.plot(jobGrowth[ii], label='1937-05-01')
    elif ii == 13:
        plt.plot(jobGrowth[ii], 'k-', lw=4, label='1929-08-01')
    else:
        plt.plot(jobGrowth[ii], label=recStart[ii])
        
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel("Jobs/peak")
plt.xlabel("Time from peak")
labels = ['-1yr', 'peak', '+1yr', '+2yr', '+3yr', '+4yr',
          '+5yr', '+6yr', '+7yr', '+8yr', '+9yr', '+10yr']
plt.xticks(np.arange(0, 145, 12), labels)

x = np.linspace(0, 145, 144)
ax.axhline(1, ls='--', linewidth=1.5, color='grey')
ax.axvline(12, ls='--', linewidth=1.5, color='grey')
plt.show()
